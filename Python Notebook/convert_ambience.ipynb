# %%
import pandas as pd

# %%
df=pd.read_csv('Business_Attributes_Final.csv')
df.head()
# Out:
# C:\Users\manis\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (25) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   attributes.AcceptsInsurance attributes.Alcohol  \
# 0                         NaN    'beer_and_wine'
# 1                         NaN   u'beer_and_wine'
# 2                         NaN                NaN
# 3                         NaN                NaN
# 4                         NaN                NaN
#
#                                  attributes.Ambience attributes.BYOB  \
# 0  {'touristy': False, 'hipster': False, 'romanti...             NaN
# 1  {'romantic': False, 'intimate': False, 'touris...             NaN
# 2                                                NaN             NaN
# 3                                                NaN             NaN
# 4                                                NaN             NaN
#
# ...

# %%
df_flt = df[df['attributes.Ambience'].notna()]

# %%
df_flt['attributes.Ambience'] = df_flt['attributes.Ambience'].apply(lambda x: eval(x))

# %%
data = [df_flt['attributes.Ambience'], df_flt['business_id']]

headers = ["attributes_Ambience", "business_id"]

df3 = pd.concat(data, axis=1, keys=headers)

# %%
type(df3['business_id'][0])

df3.shape
# Out:
# (43882, 2)

# %%
df3.dropna(inplace=True)

# %%
out = df3.to_json(orient='records')[1:-1].replace('},{', '} {')

# %%
import json
count = 0
final_data = []
for index, row in df3.iterrows():
    temp_dict = row['attributes_Ambience']
    temp_dict['business_id_orig'] = row['business_id']
    final_data.append(temp_dict)

with open('Business_Ambience_Attributes.json', 'a') as outfile:
    json.dump(final_data, outfile, indent=2)
